# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('Computer-Vision-with-Python/Computer-Vision-with-Python/DATA/dog_backpack.jpg')
pic1 = pic.resize((500,500))
pic1
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x2380B569EF0>
